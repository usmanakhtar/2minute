# %% [markdown]
# <a href="https://colab.research.google.com/github/usmanakhtar/2minute/blob/master/Copy_of_Pricing_for_Pooled_Ride.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **KPI-I: Service rate**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

PR = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-2-ServiceRate/Pooled-Rides.csv')
#print(PR)
SR = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-2-ServiceRate/Solo-Rides.csv')
#print(SR)

import pandas as pd
df = PR.div(SR, level=1, fill_value=1)
#print (df)

import matplotlib.pyplot as plt
import seaborn as sns
plt.title('Pooled-Rides/SoloRides Ratio')
sns.heatmap(data = df,annot=True,fmt=".2f",cmap='viridis')
plt.xlabel('number of Travellers',fontsize=10)
plt.ylabel('number of Drivers',fontsize=10)
# Out:
# Text(50.722222222222214, 0.5, 'number of Drivers')

# %% [markdown]
# **Metric 1: Plotting Pooled Rides / Solo Rides**

# %%
PMR = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-2-ServiceRate/Profit-Maximization.csv')
#print(PMR)
SR = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-2-ServiceRate/Solo-Rides.csv')
#print(SR)
df1 = PMR.div(SR, level=1, fill_value=1)
#print (df1)

import matplotlib.pyplot as plt
import seaborn as sns
plt.title('Profit Maximization/SoloRides Ratio')
sns.heatmap(data = df1,annot=True,fmt=".2f",cmap='viridis')
plt.xlabel('number of Travellers',fontsize=10)
plt.ylabel('number of Drivers',fontsize=10)
# Out:
# Text(50.722222222222214, 0.5, 'number of Drivers')

# %% [markdown]
# **Creating DataFrame from Ratio Lists**

# %%
compdf=df.compare(df1,align_axis=0,keep_shape=True,keep_equal=True).rename(index={'self':'PR/Solo','other':'PMR/solo'},level=-1)

# %%
compdf  # data frame for comparision of ratios
# Out:
#               0       100       200       300       400       500
# 0 PR/Solo   1.0  0.850000  1.121212  0.662500  1.093333  1.242424
#   PMR/solo  1.0  1.264706  1.272727  1.145625  1.100000  1.636364
# 1 PR/Solo   1.0  1.045455  0.946809  0.921176  0.791169  1.014286
#   PMR/solo  1.0  0.931818  0.765957  1.488235  0.844156  1.500000
# 2 PR/Solo   1.0  0.928571  1.034286  1.043812  1.124476  0.948097
#   PMR/solo  1.0  0.994898  1.034286  1.026764  1.181818  1.314879
# 3 PR/Solo   1.0  1.018367  1.000000  0.985859  1.094203  0.954469
#   PMR/solo  1.0  1.010204  0.991960  0.993232  1.239130  1.146712
# 4 PR/Solo   1.0  1.000000  1.010152  0.992951  1.012920  0.990361
#   PMR/solo  1.0  0.989899  1.000000  0.996979  1.018088  1.072289
# 5 PR/Solo   1.0  0.989899  1.015385  1.011224  0.992405  1.098655
#   PMR/solo  1.0  1.000000  1.015385  1.016327  0.992405  1.109865

# %%
plt.rcParams["figure.figsize"] = [7, 4.50]
plt.rcParams["figure.autolayout"] = True
plt.title('comparing both ratios')
sns.heatmap(data = compdf,annot=True,fmt=".2f",cmap='viridis')
plt.xlabel('number of Travellers',fontsize=10)
plt.ylabel('number of Drivers',fontsize=10)
# Out:
# Text(9.44444444444446, 0.5, 'number of Drivers')

# %% [markdown]
# **Without Ratios (HeatMap)**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

plt.rcParams["figure.figsize"] = [12.50, 3.50]
plt.rcParams["figure.autolayout"] = True


solo = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-2-ServiceRate/Solo-Rides.csv')
profitmax =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-2-ServiceRate/Profit-Maximization.csv')
pooled =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-2-ServiceRate/Pooled-Rides.csv')

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3)
fig.subplots_adjust(wspace=1.01)


s = sns.heatmap(profitmax, annot=True,  fmt=".2f", cmap='viridis', ax=ax1, vmin=0,vmax=100)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Service Rate for Profit Maximization')

s = sns.heatmap(pooled, annot=True, fmt=".2f", cmap='viridis', ax=ax2, vmin=0,vmax=100)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Service Rate for Pooled Rides')

s = sns.heatmap(solo, annot=True, fmt=".2f", cmap='viridis', ax=ax3, vmin=0,vmax=100)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Service Rate for Solo Rides')

txt="I need the caption to be present a little below X-axis"
#ax3.yaxis.tick_right()

fig.subplots_adjust(wspace=0.001)
plt.show()
fig.savefig('ServiceRate.png', dpi=600)

# %% [markdown]
# # **Comparison of Service Rate**

# %%
import pandas as pd

data2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-2-ServiceRate/Solo-Rides.csv')
data1 =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-2-ServiceRate/Profit-Maximization.csv')
data =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-2-ServiceRate/Pooled-Rides.csv')


colListPR=[]
for column in data.columns:

    # Storing the rows of a column
    # into a temporary list
    li =data[column].tolist()

    # appending the temporary list
    colListPR.append(li)

# Printing the final list
#print(colListPR)


colListPM=[]
for column in data1.columns:

    li =data1[column].tolist()

    colListPM.append(li)

#print(colListPM)

colListSR=[]
for column in data2.columns:

    li =data2[column].tolist()

    colListSR.append(li)

#print(colListSR)

import numpy as np
import matplotlib.pyplot as plt

flatPR= [y for sublist in colListPR for y in sublist]
#flatPR
#plt.boxplot(flatPR)


import numpy as np
import matplotlib.pyplot as plt

flatSR= [y for sublist in colListSR for y in sublist]
#flatSR
#plt.boxplot(flatSR)

import numpy as np
import matplotlib.pyplot as plt

flatPM= [y for sublist in colListPM for y in sublist]
#flatPM
#plt.boxplot(flatPM)

from plotly.offline import plot, iplot, init_notebook_mode
import plotly.graph_objs as go
init_notebook_mode(connected=True)

import plotly.graph_objects as go
from plotly.subplots import make_subplots
fig = go.Figure()
fig.update_layout(autosize=False,width=750,height=550,)

fig.add_trace(go.Box(y=flatPM,name="Profit-Maximization"))
fig.add_trace(go.Box(y=flatPR,name="Pooled-Rides"))
fig.add_trace(go.Box(y=flatSR,name="Solo-Rides"))
fig.update_layout(title='KPI 1 Analysis for Service rate',xaxis=dict(title='Drivers'),yaxis=dict(title='Rides'))
fig.show(renderer="colab")
plt.savefig("KPI1Analysis.jpg")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d43ba2fd-8c43-47fd-a09b-eccde9add8bc" class="plotly-graph-div" style="height:550px; width:750px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d43ba2fd-8c43-47fd-a09b-eccde9add8bc")) {                    Plotly.newPlot(                        "d43ba2fd-8c43-47fd-a09b-eccde9add8bc",                        [{"name":"Profit-Maximization","y":[5,10,20,30,40,50,43.0,82.0,97.5,99.0,98.0,99.0,21.0,36.0,90.5,98.7,98.5,99.0,18.33,25.3,60.23,98.33,99.0,99.6,8.25,16.25,42.25,85.5,98.5,98.0,10.8,21.0,38.0,68.0,89.0,99.0],"type":"box"},{"name":"Pooled-Rides","y":[5,10,20,30,40,50,28.9,92.0,91.0,99.8,99.0,98.0,18.5,44.5,90.5,99.5,99.5,99.0,10.6,15.66,61.23,97.6,98.6,99.1,8.2,15.23,40.2,75.5,98.0,98.0,8.2,14.2,27.4,56.6,82.2,98.0],"type":"box"},{"name":"Solo-Rides","y":[5,10,20,30,40,50,34,88,98,98,99,99,16.5,47.0,87.5,99.5,98.5,97.5,16.0,17.0,58.66,99.0,99.3,98.0,7.5,19.25,35.75,69.0,96.75,98.75,6.6,14.0,28.9,59.3,83.0,89.2],"type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2 ...

# %%
import warnings
warnings.simplefilter('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
#fig= plt.figure(figsize=(100,50),dpi=600)

plt.rcParams["figure.figsize"] = (8,5)


fig,ax =plt.subplots()
plt.title('Service Rate')
sns.distplot(flatPR,hist=False,label='Pooled')
sns.distplot(flatPM,hist=False,label='Profit Maximization')
sns.distplot(flatSR,hist=False,label='Solo')
plt.xlabel('Drivers',fontsize=13)
plt.ylabel('Rides',fontsize=13)

plt.legend(fontsize=10)
#plt.savefig("Revenue.jpg")
plt.show()

# %% [markdown]
# # **KPI-2: Idle Time**

# %%
import pandas as pd

data2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-3-IdleTime/IdleTime_Solo-Rides.csv')
data1 =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-3-IdleTime/IdleTime_Profit-Maximization.csv')
data =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-3-IdleTime/IdleTime_Pooled-Rides.csv')

for col in data.columns:
    data[col]=data[col]//3600
    data.head()

for col in data1.columns:
    data1[col]=data1[col]//3600
    data1.head()


for col in data1.columns:
    data2[col]=data2[col]//3600
    data2.head()

colListPR=[]
for column in data.columns:

    # Storing the rows of a column
    # into a temporary list
    li =data[column].tolist()

    # appending the temporary list
    colListPR.append(li)

# Printing the final list
#print(colListPR)


colListPM=[]
for column in data1.columns:

    li =data1[column].tolist()

    colListPM.append(li)

#print(colListPM)

colListSR=[]
for column in data2.columns:

    li =data2[column].tolist()

    colListSR.append(li)

#print(colListSR)

import numpy as np
import matplotlib.pyplot as plt

flatPR= [y for sublist in colListPR for y in sublist]
#flatPR
#plt.boxplot(flatPR)


import numpy as np
import matplotlib.pyplot as plt

flatSR= [y for sublist in colListSR for y in sublist]
#flatSR
#plt.boxplot(flatSR)

import numpy as np
import matplotlib.pyplot as plt

flatPM= [y for sublist in colListPM for y in sublist]
#flatPM
#plt.boxplot(flatPM)

import plotly.graph_objects as go
from plotly.subplots import make_subplots
fig = go.Figure()
fig.update_layout(autosize=False,width=750,height=550,)

fig.add_trace(go.Box(y=flatPM,name="Profit-Maximization"))
fig.add_trace(go.Box(y=flatPR,name="Pooled-Rides"))
fig.add_trace(go.Box(y=flatSR,name="Solo-Rides"))
fig.update_layout(title='Analysis of Idle Time',xaxis=dict(title='Comparison of Strategies'),yaxis=dict(title='Idle Time'))
fig.show(renderer="colab")
#plt.savefig("KPI1Analysis.jpg")


#############################################
import warnings
warnings.simplefilter('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
#fig= plt.figure(figsize=(100,50),dpi=600)

plt.rcParams["figure.figsize"] = (8,5)


fig,ax =plt.subplots()
plt.title('Idle Time')

sns.distplot(flatPM,hist=False,label='Profit Maximization', bins=int(180/5), kde_kws={'linewidth': 1, 'shade':True})



sns.distplot(flatPR,hist=False,label='Pooled',  bins=int(180/5), kde_kws={'linewidth': 1, 'shade':True})

sns.distplot(flatSR,hist=False,label='Solo',  bins=int(180/5), kde_kws={'linewidth': 1, 'shade':True})
plt.xlabel('Drivers',fontsize=13)
plt.ylabel('Rides',fontsize=13)

plt.legend(fontsize=10)
#plt.savefig("Revenue.jpg")
plt.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7469800c-5bef-418d-940f-5059e6c35f61" class="plotly-graph-div" style="height:550px; width:750px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7469800c-5bef-418d-940f-5059e6c35f61")) {                    Plotly.newPlot(                        "7469800c-5bef-418d-940f-5059e6c35f61",                        [{"name":"Profit-Maximization","y":[0,0,0,0,0,9,51,52,78,109,7,28,37,64,141,15,13,38,74,113,21,6,31,58,100,25,13,18,47,75],"type":"box"},{"name":"Pooled-Rides","y":[0,0,0,0,0,9,46,56,78,107,16,33,35,62,138,11,12,35,89,144,22,7,38,66,117,6,13,18,54,82],"type":"box"},{"name":"Solo-Rides","y":[0,0,0,0,0,9,51,53,80,108,10,16,36,66,145,14,3,38,100,162,21,7,43,66,125,18,13,18,59,95],"type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"tic ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

plt.rcParams["figure.figsize"] = [12.50, 3.50]
plt.rcParams["figure.autolayout"] = True

solo = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-3-IdleTime/IdleTime_Solo-Rides.csv')

profitmax =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-3-IdleTime/IdleTime_Profit-Maximization.csv')
pooled =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-3-IdleTime/IdleTime_Pooled-Rides.csv')



for col in solo.columns:
    solo[col]=solo[col]//3600
    solo.head()

for col in profitmax.columns:
    profitmax[col]=profitmax[col]//3600
    profitmax.head()


for col in pooled.columns:
    pooled[col]=pooled[col]//3600
    pooled.head()


fig, (ax1, ax2, ax3) = plt.subplots(ncols=3)
fig.subplots_adjust(wspace=1.01)


s = sns.heatmap(profitmax, annot=True,  fmt=".1f", cmap='viridis', ax=ax1)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'IdleTime of Profit Maximization')

s = sns.heatmap(pooled, annot=True, fmt=".1f", cmap='viridis', ax=ax2)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'IdleTime of   Pooled Rides')

s = sns.heatmap(solo, annot=True, fmt=".1f", cmap='viridis', ax=ax3)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'IdleTime of Solo Rides')

txt="I need the caption to be present a little below X-axis"
#ax3.yaxis.tick_right()

fig.subplots_adjust(wspace=0.001)
plt.show()
#fig.savefig('ServiceRate.png', dpi=600)

# %% [markdown]
# # **KPI-3: Revenue**

# %%
import pandas as pd

data2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-1-Revenue/Revenue_Solo-Rides.csv')

data1 =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-1-Revenue/Revenue_Profit-Maximization.csv')
data =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-1-Revenue/Revenue_Pooled-Rides.csv')

data

colListPR=[]
for column in data.columns:

    # Storing the rows of a column
    # into a temporary list
    li =data[column].tolist()

    # appending the temporary list
    colListPR.append(li)

# Printing the final list
#print(colListPR)


colListPM=[]
for column in data1.columns:

    li =data1[column].tolist()

    colListPM.append(li)

print(colListPM)

colListSR=[]
for column in data2.columns:

    li =data2[column].tolist()

    colListSR.append(li)

#print(colListSR)

import numpy as np
import matplotlib.pyplot as plt

flatPR= [y for sublist in colListPR for y in sublist]
#flatPR
#plt.boxplot(flatPR)


import numpy as np
import matplotlib.pyplot as plt

flatSR= [y for sublist in colListSR for y in sublist]
#flatSR
#plt.boxplot(flatSR)

import numpy as np
import matplotlib.pyplot as plt

flatPM= [y for sublist in colListPM for y in sublist]
#flatPM
#plt.boxplot(flatPM)

import plotly.graph_objects as go
from plotly.subplots import make_subplots
fig = go.Figure()
fig.update_layout(autosize=False,width=750,height=550,)

fig.add_trace(go.Box(y=flatPM,name="Profit-Maximization"))
fig.add_trace(go.Box(y=flatPR,name="Pooled-Rides"))
fig.add_trace(go.Box(y=flatSR,name="Solo-Rides"))
fig.update_layout(title='Analysis of Revenue',xaxis=dict(title='Comparsion of Strategies'),yaxis=dict(title='Revenue'))
fig.show(renderer="colab")
#plt.savefig("KPI1Analysis.jpg")


#############################################
# Out:
# [[10, 20, 30, 40, 50], [245.44, 260.474, 270.851, 278.426, 256.914], [537.232, 528.278, 513.209, 524.692, 525.275], [782.145, 802.675, 772.192, 780.662, 855.0], [943.0, 1125.707, 1069.642, 1021.134, 1034.751], [1032.158, 1312.125, 1328.86, 1309.853, 1292.01]]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f261b254-d0ed-4b72-be56-f3bdb1abf320" class="plotly-graph-div" style="height:550px; width:750px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f261b254-d0ed-4b72-be56-f3bdb1abf320")) {                    Plotly.newPlot(                        "f261b254-d0ed-4b72-be56-f3bdb1abf320",                        [{"name":"Profit-Maximization","y":[10,20,30,40,50,245.44,260.474,270.851,278.426,256.914,537.232,528.278,513.209,524.692,525.275,782.145,802.675,772.192,780.662,855.0,943.0,1125.707,1069.642,1021.134,1034.751,1032.158,1312.125,1328.86,1309.853,1292.01],"type":"box"},{"name":"Pooled-Rides","y":[10,20,30,40,50,247.43,268.238,261.43,268.426,255.594,523.59,518.779,511.5649,520.971,515.315,721.9399,757.78,793.076,799.459,810.0,837.114,1055.67,948.0,980.23,1000.1,900.8,1100.25,1200.3,1250.69,1190.01],"type":"box"},{"name":"Solo-Rides","y":[10,20,30,40,50,229.494,261.535,278.411,258.073,260.568,500.947,533.265,525.366,520.677,549.562,748.644,812.443,783.077,772.0,800.0,889.98,950.55,855.23,900.25,980.56,810.23,1050.25,1100.23,1150.23,1082.25],"type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}] ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

plt.rcParams["figure.figsize"] = [12.50, 3.50]
plt.rcParams["figure.autolayout"] = True

solo = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-1-Revenue/Revenue_Solo-Rides.csv')

profitmax =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-1-Revenue/Revenue_Profit-Maximization.csv')
pooled =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-1-Revenue/Revenue_Pooled-Rides.csv')



fig, (ax1, ax2, ax3) = plt.subplots(ncols=3)
fig.subplots_adjust(wspace=1.01)


s = sns.heatmap(profitmax, annot=True,  fmt=".1f", cmap='viridis', ax=ax1)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Revenue of Profit Maximization')

s = sns.heatmap(pooled, annot=True, fmt=".1f", cmap='viridis', ax=ax2)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Revenue of   Pooled Rides')

s = sns.heatmap(solo, annot=True, fmt=".1f", cmap='viridis', ax=ax3)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Revenue of Solo Rides')

txt="I need the caption to be present a little below X-axis"
#ax3.yaxis.tick_right()

fig.subplots_adjust(wspace=0.001)
plt.show()
#fig.savefig('ServiceRate.png', dpi=600)

# %% [markdown]
# # **KPI-4: Arrival Time (time to arrive for traveller)**

# %%
import pandas as pd

data2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-4-ArrivalTime/ArrivalTime_Solo-Rides.csv')
data1 =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-4-ArrivalTime/ArrivalTime_Profit-Maximization.csv')
data =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-4-ArrivalTime/ArrivalTime_Pooled-Rides.csv')


for col in data.columns:
    data[col]=data[col]//3600
    data.head()

for col in data1.columns:
    data1[col]=data1[col]//3600
    data1.head()


for col in data1.columns:
    data2[col]=data2[col]//3600
    data2.head()


colListPR=[]
for column in data.columns:

    # Storing the rows of a column
    # into a temporary list
    li =data[column].tolist()

    # appending the temporary list
    colListPR.append(li)

# Printing the final list
#print(colListPR)


colListPM=[]
for column in data1.columns:

    li =data1[column].tolist()

    colListPM.append(li)

print(colListPM)

colListSR=[]
for column in data2.columns:

    li =data2[column].tolist()

    colListSR.append(li)

#print(colListSR)

import numpy as np
import matplotlib.pyplot as plt

flatPR= [y for sublist in colListPR for y in sublist]
#flatPR
#plt.boxplot(flatPR)


import numpy as np
import matplotlib.pyplot as plt

flatSR= [y for sublist in colListSR for y in sublist]
#flatSR
#plt.boxplot(flatSR)

import numpy as np
import matplotlib.pyplot as plt

flatPM= [y for sublist in colListPM for y in sublist]
#flatPM
#plt.boxplot(flatPM)

import plotly.graph_objects as go
from plotly.subplots import make_subplots
fig = go.Figure()
fig.update_layout(autosize=False,width=750,height=550,)

fig.add_trace(go.Box(y=flatPM,name="Profit-Maximization"))
fig.add_trace(go.Box(y=flatPR,name="Pooled-Rides"))
fig.add_trace(go.Box(y=flatSR,name="Solo-Rides"))
fig.update_layout(title='Arrival Time',xaxis=dict(title='Comparsion of Strategies'),yaxis=dict(title='Arrival Time'))
fig.show(renderer="colab")
#plt.savefig("KPI1Analysis.jpg")


#############################################
# Out:
# [[0, 0, 0, 0, 0], [4, 60, 80, 137, 180], [5, 27, 46, 91, 144], [20, 11, 42, 70, 173], [21, 6, 31, 58, 100], [24, 14, 17, 35, 84]]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="bee000ce-66c9-4a2d-b6cc-de3c9e422594" class="plotly-graph-div" style="height:550px; width:750px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bee000ce-66c9-4a2d-b6cc-de3c9e422594")) {                    Plotly.newPlot(                        "bee000ce-66c9-4a2d-b6cc-de3c9e422594",                        [{"name":"Profit-Maximization","y":[0,0,0,0,0,4,60,80,137,180,5,27,46,91,144,20,11,42,70,173,21,6,31,58,100,24,14,17,35,84],"type":"box"},{"name":"Pooled-Rides","y":[0,0,0,0,0,3,48,83,157,195,4,28,83,110,169,20,11,11,93,159,20,7,38,66,117,24,12,13,46,94],"type":"box"},{"name":"Solo-Rides","y":[0,0,0,0,0,3,50,83,159,207,4,28,83,116,182,20,11,46,104,173,21,7,43,66,125,24,12,13,56,100],"type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth": ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

plt.rcParams["figure.figsize"] = [12.50, 3.50]
plt.rcParams["figure.autolayout"] = True

solo = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-4-ArrivalTime/ArrivalTime_Solo-Rides.csv')
profitmax =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-4-ArrivalTime/ArrivalTime_Profit-Maximization.csv')
pooled =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-4-ArrivalTime/ArrivalTime_Pooled-Rides.csv')




for col in solo.columns:
    solo[col]=solo[col]//3600
    solo.head()

for col in profitmax.columns:
    profitmax[col]=profitmax[col]//3600
    profitmax.head()


for col in pooled.columns:
    pooled[col]=pooled[col]//3600
    pooled.head()


fig, (ax1, ax2, ax3) = plt.subplots(ncols=3)
fig.subplots_adjust(wspace=1.01)


s = sns.heatmap(profitmax, annot=True,  fmt=".1f", cmap='viridis', ax=ax1)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Arrival Time of Profit Maximization')

s = sns.heatmap(pooled, annot=True, fmt=".1f", cmap='viridis', ax=ax2)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Arrival Time  of   Pooled Rides')

s = sns.heatmap(solo, annot=True, fmt=".1f", cmap='viridis', ax=ax3)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Arrival Time  of Solo Rides')

txt="I need the caption to be present a little below X-axis"
#ax3.yaxis.tick_right()

fig.subplots_adjust(wspace=0.001)
plt.show()
#fig.savefig('ServiceRate.png', dpi=600)

# %% [markdown]
# # **KPI-5: Travel Time (Paid Time)**

# %%
import pandas as pd

data2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-5-TravelTime/Travel_Solo-Rides.csv')
data1 =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-5-TravelTime/Travel_Profit-Maximization.csv')
data =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-5-TravelTime/Travel_Solo-Rides.csv')


for col in data.columns:
    data[col]=data[col]//60
    data.head()

for col in data1.columns:
    data1[col]=data1[col]//60
    data1.head()


for col in data1.columns:
    data2[col]=data2[col]//60
    data2.head()

colListPR=[]
for column in data.columns:

    # Storing the rows of a column
    # into a temporary list
    li =data[column].tolist()

    # appending the temporary list
    colListPR.append(li)

# Printing the final list
#print(colListPR)


colListPM=[]
for column in data1.columns:

    li =data1[column].tolist()

    colListPM.append(li)

print(colListPM)

colListSR=[]
for column in data2.columns:

    li =data2[column].tolist()

    colListSR.append(li)

#print(colListSR)

import numpy as np
import matplotlib.pyplot as plt

flatPR= [y for sublist in colListPR for y in sublist]
#flatPR
#plt.boxplot(flatPR)


import numpy as np
import matplotlib.pyplot as plt

flatSR= [y for sublist in colListSR for y in sublist]
#flatSR
#plt.boxplot(flatSR)

import numpy as np
import matplotlib.pyplot as plt

flatPM= [y for sublist in colListPM for y in sublist]
#flatPM
#plt.boxplot(flatPM)

import plotly.graph_objects as go
from plotly.subplots import make_subplots
fig = go.Figure()
fig.update_layout(autosize=False,width=750,height=550,)

fig.add_trace(go.Box(y=flatPM,name="Profit-Maximization"))
fig.add_trace(go.Box(y=flatPR,name="Pooled-Rides"))
fig.add_trace(go.Box(y=flatSR,name="Solo-Rides"))
fig.update_layout(title='Travel Time',xaxis=dict(title='Comparsion of Strategies'),yaxis=dict(title='Travel Time'))
fig.show(renderer="colab")
#plt.savefig("KPI1Analysis.jpg")


#############################################

import warnings
warnings.simplefilter('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
#fig= plt.figure(figsize=(100,50),dpi=600)

plt.rcParams["figure.figsize"] = (8,5)


fig,ax =plt.subplots()
plt.title('Travel Time')
sns.distplot(flatPR,hist=False,label='Pooled')
sns.distplot(flatPM,hist=False,label='Profit Maximization')
sns.distplot(flatSR,hist=False,label='Solo')
plt.xlabel('Travel Time',fontsize=13)
plt.ylabel('Rides',fontsize=13)

plt.legend(fontsize=10)
#plt.savefig("Revenue.jpg")
plt.show()
# Out:
# [[0, 0, 0, 0, 0], [281, 400, 378, 345, 356], [705, 644, 667, 667, 683], [928, 983, 917, 988, 983], [1132, 1256, 1186, 1210, 1231], [359, 1466, 1512, 1445, 1468]]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3b2bacc3-b1c5-41d5-a07b-0a9f6a2c00d4" class="plotly-graph-div" style="height:550px; width:750px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b2bacc3-b1c5-41d5-a07b-0a9f6a2c00d4")) {                    Plotly.newPlot(                        "3b2bacc3-b1c5-41d5-a07b-0a9f6a2c00d4",                        [{"name":"Profit-Maximization","y":[0,0,0,0,0,281,400,378,345,356,705,644,667,667,683,928,983,917,988,983,1132,1256,1186,1210,1231,359,1466,1512,1445,1468],"type":"box"},{"name":"Pooled-Rides","y":[0,0,0,0,0,271,346,376,379,372,614,665,697,696,742,929,964,983,988,983,1138,1256,1186,1254,1187,359,1399,1456,1504,1469],"type":"box"},{"name":"Solo-Rides","y":[0,0,0,0,0,271,346,376,379,372,614,665,697,696,742,929,964,983,988,983,1138,1256,1186,1254,1187,359,1399,1456,1504,1469],"type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0 ...

# %% [markdown]
# ## **KPI - 6: Waiting Time (Time Waiting for Travellers)**

# %%
import pandas as pd

data2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-6-WaitingTime/Waiting_Pooled-Rides.csv')
data1 =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-6-WaitingTime/Waiting_Profit-Maximization.csv')
data =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-6-WaitingTime/Waiting_Solo-Rides.csv')


for col in data.columns:
    data[col]=data[col]//3600
    data.head()

for col in data1.columns:
    data1[col]=data1[col]//3600
    data1.head()


for col in data1.columns:
    data2[col]=data2[col]//3600
    data2.head()

colListPR=[]
for column in data.columns:

    # Storing the rows of a column
    # into a temporary list
    li =data[column].tolist()

    # appending the temporary list
    colListPR.append(li)

# Printing the final list
#print(colListPR)


colListPM=[]
for column in data1.columns:

    li =data1[column].tolist()

    colListPM.append(li)

print(colListPM)

colListSR=[]
for column in data2.columns:

    li =data2[column].tolist()

    colListSR.append(li)

#print(colListSR)

import numpy as np
import matplotlib.pyplot as plt

flatPR= [y for sublist in colListPR for y in sublist]
#flatPR
#plt.boxplot(flatPR)


import numpy as np
import matplotlib.pyplot as plt

flatSR= [y for sublist in colListSR for y in sublist]
#flatSR
#plt.boxplot(flatSR)

import numpy as np
import matplotlib.pyplot as plt

flatPM= [y for sublist in colListPM for y in sublist]
#flatPM
#plt.boxplot(flatPM)

import plotly.graph_objects as go
from plotly.subplots import make_subplots
fig = go.Figure()
fig.update_layout(autosize=False,width=750,height=550,)

fig.add_trace(go.Box(y=flatPM,name="Profit-Maximization"))
fig.add_trace(go.Box(y=flatPR,name="Pooled-Rides"))
fig.add_trace(go.Box(y=flatSR,name="Solo-Rides"))
fig.update_layout(title='Waiting Time',xaxis=dict(title='Comparsion of Strategies'),yaxis=dict(title='Waiting Time'))
fig.show(renderer="colab")
#plt.savefig("KPI1Analysis.jpg")


#############################################

import warnings
warnings.simplefilter('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
#fig= plt.figure(figsize=(100,50),dpi=600)

plt.rcParams["figure.figsize"] = (8,5)


fig,ax =plt.subplots()
plt.title('Waiting Time')
sns.distplot(flatPR,hist=False,label='Pooled')
sns.distplot(flatPM,hist=False,label='Profit Maximization')
sns.distplot(flatSR,hist=False,label='Solo')
plt.xlabel('Waiting Time',fontsize=13)
plt.ylabel('Rides',fontsize=13)

plt.legend(fontsize=10)
#plt.savefig("Revenue.jpg")
plt.show()
# Out:
# [[0, 0, 0, 0, 0], [20, 45, 41, 24, 38], [108, 99, 92, 88, 86], [193, 175, 168, 203, 170], [240, 236, 248, 244, 251], [27, 344, 323, 325, 314]]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f085e7c3-078f-48d1-b886-bfa49eec0fdf" class="plotly-graph-div" style="height:550px; width:750px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f085e7c3-078f-48d1-b886-bfa49eec0fdf")) {                    Plotly.newPlot(                        "f085e7c3-078f-48d1-b886-bfa49eec0fdf",                        [{"name":"Profit-Maximization","y":[0,0,0,0,0,20,45,41,24,38,108,99,92,88,86,193,175,168,203,170,240,236,248,244,251,27,344,323,325,314],"type":"box"},{"name":"Pooled-Rides","y":[0,0,0,0,0,21,37,32,25,39,127,113,87,72,89,166,157,177,205,173,245,209,250,245,255,35,344,324,327,318],"type":"box"},{"name":"Solo-Rides","y":[0,0,0,0,0,20,23,37,25,39,93,86,104,84,80,22,168,157,205,173,248,255,250,246,254,39,344,324,327,320],"type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","m ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

plt.rcParams["figure.figsize"] = [12.50, 3.50]
plt.rcParams["figure.autolayout"] = True

solo = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-6-WaitingTime/Waiting_Solo-Rides.csv')

profitmax =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-6-WaitingTime/Waiting_Profit-Maximization.csv')
pooled =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-6-WaitingTime/Waiting_Pooled-Rides.csv')

for col in solo.columns:
    solo[col]=solo[col]//3600
    solo.head()

for col in profitmax.columns:
    profitmax[col]=profitmax[col]//3600
    profitmax.head()


for col in pooled.columns:
    pooled[col]=pooled[col]//3600
    pooled.head()

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3)
fig.subplots_adjust(wspace=1.01)


s = sns.heatmap(profitmax, annot=True,  fmt=".2f", cmap='viridis', ax=ax1)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Waiting time of Profit Maximization')

s = sns.heatmap(pooled, annot=True, fmt=".2f", cmap='viridis', ax=ax2)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Waiting time of   Pooled Rides')

s = sns.heatmap(solo, annot=True, fmt=".2f", cmap='viridis', ax=ax3)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Waiting time of Solo Rides')

txt="I need the caption to be present a little below X-axis"
#ax3.yaxis.tick_right()

fig.subplots_adjust(wspace=0.001)
plt.show()
#fig.savefig('ServiceRate.png', dpi=600)

# %% [markdown]
# ## **KPI: 7 - Distance Travelled**

# %%
import pandas as pd

data2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-7-VehKM/Pooled-Rides.csv')
data1 =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-7-VehKM/Profit-Maximization.csv')
data =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-7-VehKM/Solo-Rides.csv')



colListPR=[]
for column in data.columns:

    # Storing the rows of a column
    # into a temporary list
    li =data[column].tolist()

    # appending the temporary list
    colListPR.append(li)

# Printing the final list
#print(colListPR)


colListPM=[]
for column in data1.columns:

    li =data1[column].tolist()

    colListPM.append(li)

print(colListPM)

colListSR=[]
for column in data2.columns:

    li =data2[column].tolist()

    colListSR.append(li)

#print(colListSR)

import numpy as np
import matplotlib.pyplot as plt

flatPR= [y for sublist in colListPR for y in sublist]
#flatPR
#plt.boxplot(flatPR)


import numpy as np
import matplotlib.pyplot as plt

flatSR= [y for sublist in colListSR for y in sublist]
#flatSR
#plt.boxplot(flatSR)

import numpy as np
import matplotlib.pyplot as plt

flatPM= [y for sublist in colListPM for y in sublist]
#flatPM
#plt.boxplot(flatPM)

import plotly.graph_objects as go
from plotly.subplots import make_subplots
fig = go.Figure()
fig.update_layout(autosize=False,width=750,height=550,)

fig.add_trace(go.Box(y=flatPM,name="Profit-Maximization"))
fig.add_trace(go.Box(y=flatPR,name="Pooled-Rides"))
fig.add_trace(go.Box(y=flatSR,name="Solo-Rides"))
fig.update_layout(title='Distance Travelled in KM',xaxis=dict(title='Comparsion of Strategies'),yaxis=dict(title='Distance Travelled'))
fig.show(renderer="colab")
#plt.savefig("KPI1Analysis.jpg")


#############################################

import warnings
warnings.simplefilter('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
#fig= plt.figure(figsize=(100,50),dpi=600)

plt.rcParams["figure.figsize"] = (8,5)


fig,ax =plt.subplots()
plt.title('Waiting Time')
sns.distplot(flatPR,hist=False,label='Pooled')
sns.distplot(flatPM,hist=False,label='Profit Maximization')
sns.distplot(flatSR,hist=False,label='Solo')
plt.xlabel('Waiting Time',fontsize=13)
plt.ylabel('Rides',fontsize=13)

plt.legend(fontsize=10)
#plt.savefig("Revenue.jpg")
plt.show()
# Out:
# [[10, 20, 30, 40, 50], [241.703, 256.513, 275.763, 264.862, 239.977], [224.187, 506.603, 531.918, 535.765, 478.124], [208.52, 437.075, 775.989, 745.393, 782.003], [210.818, 443.378, 682.287, 1045.725, 1055.842], [276.805, 366.167, 743.084, 1120.411, 1287.775]]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d50be84e-f861-440c-8b43-0b197dbfe704" class="plotly-graph-div" style="height:550px; width:750px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d50be84e-f861-440c-8b43-0b197dbfe704")) {                    Plotly.newPlot(                        "d50be84e-f861-440c-8b43-0b197dbfe704",                        [{"name":"Profit-Maximization","y":[10,20,30,40,50,241.703,256.513,275.763,264.862,239.977,224.187,506.603,531.918,535.765,478.124,208.52,437.075,775.989,745.393,782.003,210.818,443.378,682.287,1045.725,1055.842,276.805,366.167,743.084,1120.411,1287.775],"type":"box"},{"name":"Pooled-Rides","y":[10,20,30,40,50,246.587,273.868,276.638,276.979,246.862,256.922,534.113,542.495,558.945,513.281,179.722,412.169,670.997,807.086,779.059,180.696,471.77,757.794,1070.971,1080.723,199.337,434.722,622.978,1217.192,1294.355],"type":"box"},{"name":"Solo-Rides","y":[10,20,30,40,50,247.432,276.41,274.037,298.152,282.529,183.674,391.833,514.931,531.052,495.813,267.717,475.737,778.669,813.427,764.379,235.664,395.59,729.415,1058.536,1040.222,212.303,434.722,699.814,1070.287,1237.308],"type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"out ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

plt.rcParams["figure.figsize"] = [12.50, 3.50]
plt.rcParams["figure.autolayout"] = True

solo = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-7-VehKM/Solo-Rides.csv')

profitmax =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-7-VehKM/Profit-Maximization.csv')
pooled =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/KPI-7-VehKM/Pooled-Rides.csv')


fig, (ax1, ax2, ax3) = plt.subplots(ncols=3)
fig.subplots_adjust(wspace=1.01)


s = sns.heatmap(profitmax, annot=True,  fmt=".0f", cmap='viridis', ax=ax1)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Distance Travelled (KM) of Profit Maximization')

s = sns.heatmap(pooled, annot=True, fmt=".0f", cmap='viridis', ax=ax2)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Distance Travelled (KM) of   Pooled Rides')

s = sns.heatmap(solo, annot=True, fmt=".0f", cmap='viridis', ax=ax3)
s.set(xlabel='number of Travellers', ylabel='number of Drivers', title = 'Distance Travelled (KM) of Solo Rides')

txt="I need the caption to be present a little below X-axis"
#ax3.yaxis.tick_right()

fig.subplots_adjust(wspace=0.001)
plt.show()
#fig.savefig('ServiceRate.png', dpi=600)
